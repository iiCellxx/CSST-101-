# %% [markdown]
# # Define the condition

# %%
def is_ground_wet(is_raining):
  return is_raining

def will_match_light(is_ground_wet):
  return not is_ground_wet

# %% [markdown]
# # Simulating Condition

# %%
is_raining = True
is_ground_wet = is_ground_wet(is_raining)
match_lights = will_match_light(is_ground_wet)

# %% [markdown]
# # Display result

# %%
print(f"Is it raining? {'Yes' if is_raining else 'No'}")
print(f"Is the ground we? {'Yes' if is_ground_wet else 'No'}")
print(f"Will the match light? {'Yes' if match_lights else 'No'}")
# Out:
# Is it raining? Yes
# Is the ground we? Yes
# Will the match light? No

# %% [markdown]
# Exercise 1: Propositional Logic in Python.

# %%
rains = True

def ground_wet(rains):
  return rains

def match_lights(ground_wet):
  return not ground_wet

if rains:
   is_ground_wet = ground_wet(rains)
   can_match_light = match_lights(is_ground_wet)

   if can_match_light:
    print("The match will light")
   else:
    print("The match will not light")

# %% [markdown]
# EXERCISE 2: Predicate Logic Repressentation
# "All human are mortal."
# "Socrates is a human."
# "Therefore, Socrates is mortal."

# %%
def isHuman(person):
  return person == "Socrates"

def isMortal(person):
  if isHuman(person):
    return True
  else:
    return False

person = "Socrates"

if isMortal(person):
    print(f"{person} is mortal")
else:
     print(f"{person} is mortal")
# Out:
# Socrates is mortal

# %% [markdown]
# EXERCISE 3: Inference Techniques in Logic - Based Systems
# Rule "if X is true, then Y is true" Fact "X is true" Conclusion "Y is true:"

# %%
def modus_ponens(rules, facts):
    conclusions = []
    for rule in rules:
        premise, conclusion = rule
        if premise in facts:
            conclusions.append(conclusion)
    return conclusions

rules = [("X", "Y")]

facts = ["X"]

conclusions = modus_ponens(rules, facts)
print("Inferred Conclusions:", conclusions)
# Out:
# Inferred Conclusions: ['Y']

# %% [markdown]
# EXERCISE 4:

# %%
def is_hungry(H):
  return H

def eats(E):
  return E

def no_longer_hungry(NH):
  return NH

def reason(H):
  if H:
    E = eats(True)
    NH = no_longer_hungry(E)
    return NH
  else:
    return False

John_is_hungry = True
John_no_longger_hungry = reason(John_is_hungry)

print(f"Is John hungry? {John_is_hungry}")
print(f"Is John no longer hungry? {John_no_longger_hungry}")
# Out:
# Is John hungry? True
# Is John no longer hungry? True

# %% [markdown]
# IMPLEMENT A LOGIC - BASED MODEL IN PYTHON

# %%
def is_greeting(statement):
  greeting = ["hello", "hi", "hey"]
  return statement.lower() in greeting

def respond(statement):
  if is_greeting(statement):
    return "Hello! How can I help you today?"
  else:
    return "I am not sure how to respond to that."

user_input = input("User: ")
response = respond(user_input)
print(f"Chatbot: {response}")
# Out:
# User: hi
# Chatbot: Hello! How can I help you today?
